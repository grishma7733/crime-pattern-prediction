# %% [markdown]
# <a href="https://colab.research.google.com/github/grishma7733/crime-pattern-prediction/blob/main/ML_Project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data=pd.read_csv('/content/data.csv')

# %%
data.head(10)
# Out:
#           timestamp  Theft  act13  Hit and run  Assault  Kidnapping  Murder  \
# 0  28-02-2018 21:00      1      0            0        0           0       0
# 1  28-02-2018 21:15      1      0            0        0           0       0
# 2  28-02-2018 10:15      0      0            1        0           0       0
# 3  28-02-2018 10:15      0      0            1        0           0       0
# 4  28-02-2018 10:30      0      0            1        0           0       0
# 5  28-02-2018 14:15      0      0            0        1           0       0
# 6  28-02-2018 08:00      0      0            0        0           1       0
# 7  28-02-2018 03:30      0      0            0        1           0       0
# 8  28-02-2018 01:30      1      0            0        0           0       0
# 9  28-02-2018 19:00      0      0            0        1           0       0
#
#     latitude  longitude
# 0  22.737260  75.875987
# 1  22.720992  75.876083
# 2  22.736676  75.883168
# 3  22.746527  75.887139
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2068 entries, 0 to 2067
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   timestamp    2068 non-null   datetime64[ns]
#  1   Theft        2068 non-null   int64
#  2   act13        2068 non-null   int64
#  3   Hit and run  2068 non-null   int64
#  4   Assault      2068 non-null   int64
#  5   Kidnapping   2068 non-null   int64
#  6   Murder       2068 non-null   int64
#  7   latitude     2068 non-null   float64
#  8   longitude    2068 non-null   float64
# dtypes: datetime64[ns](1), float64(2), int64(6)
# memory usage: 145.5 KB

# %%
data['timestamp'] = pd.to_datetime(data['timestamp'])

# %%
data['timestamp'] = pd.to_datetime(data['timestamp'], format = '%d/%m/%Y %H:%M:%S')

# %%
data['timestamp']
# Out:
# 0      2018-02-28 21:00:00
# 1      2018-02-28 21:15:00
# 2      2018-02-28 10:15:00
# 3      2018-02-28 10:15:00
# 4      2018-02-28 10:30:00
#                ...
# 2063   2018-07-03 03:50:00
# 2064   2018-07-03 21:10:00
# 2065   2018-07-03 12:10:00
# 2066   2018-07-03 10:35:00
# 2067   2018-07-03 23:45:00
# Name: timestamp, Length: 2068, dtype: datetime64[ns]

# %%
data
# Out:
#                timestamp  Theft  act13  Hit and run  Assault  Kidnapping  \
# 0    2018-02-28 21:00:00      1      0            0        0           0
# 1    2018-02-28 21:15:00      1      0            0        0           0
# 2    2018-02-28 10:15:00      0      0            1        0           0
# 3    2018-02-28 10:15:00      0      0            1        0           0
# 4    2018-02-28 10:30:00      0      0            1        0           0
# ...                  ...    ...    ...          ...      ...         ...
# 2063 2018-07-03 03:50:00      0      0            0        1           0
# 2064 2018-07-03 21:10:00      0      0            0        1           0
# 2065 2018-07-03 12:10:00      0      0            1        0           0
# 2066 2018-07-03 10:35:00      0      0            1        0           0
# 2067 2018-07-03 23:45:00      0      0            1        0           0
#
#       Murder   latitude  longitude
# 0          0  22.737260  75.875987
# ...

# %%
column_1 = data.iloc[:,0]

db=pd.DataFrame({"year": column_1.dt.year,
              "month": column_1.dt.month,
              "day": column_1.dt.day,
              "hour": column_1.dt.hour,
              "dayofyear": column_1.dt.dayofyear,
              "week": column_1.dt.week,
              "weekofyear": column_1.dt.weekofyear,
              "dayofweek": column_1.dt.dayofweek,
              "weekday": column_1.dt.weekday,
              "quarter": column_1.dt.quarter,
             })
# Out:
# <ipython-input-9-365323ffc021>:8: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   "week": column_1.dt.week,
# <ipython-input-9-365323ffc021>:9: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   "weekofyear": column_1.dt.weekofyear,

# %%
data1=data.drop('timestamp',axis=1)

# %%
df = pd.concat([db, data1], axis=1)

# %%
df.drop(columns=['act13'], inplace=True, axis=1)

# %%
data1.dropna(inplace=True)

# %%
df.head(10)
# Out:
#    year  month  day  hour  dayofyear  week  weekofyear  dayofweek  weekday  \
# 0  2018      2   28    21         59     9           9          2        2
# 1  2018      2   28    21         59     9           9          2        2
# 2  2018      2   28    10         59     9           9          2        2
# 3  2018      2   28    10         59     9           9          2        2
# 4  2018      2   28    10         59     9           9          2        2
# 5  2018      2   28    14         59     9           9          2        2
# 6  2018      2   28     8         59     9           9          2        2
# 7  2018      2   28     3         59     9           9          2        2
# 8  2018      2   28     1         59     9           9          2        2
# 9  2018      2   28    19         59     9           9          2        2
#
#    quarter  Theft  Hit and run  Assault  Kidnapping  Murder   latitude  \
# ...

# %%
len(df.columns)
# Out:
# 17

# %%
df['month'].max()
# Out:
# 7

# %%
df['longitude'].min()
# Out:
# 75.542195

# %%
total=df.shape[0]

# %%
df1 = pd.DataFrame(data=data1, columns=['Theft', 'Hit and run', 'Assault','Kidnapping','Murder'])

# %%
df1.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
df.plot.hexbin(x='Theft',y='hour',gridsize=25)
# Out:
# <Axes: xlabel='Theft', ylabel='hour'>

# %%
X = df[['year','month','day','hour','latitude','longitude']]
Y = df[['Theft','Hit and run','Assault','Kidnapping','Murder']]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.20, random_state=50)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
knn = KNeighborsClassifier(n_neighbors=9)
knn.fit(X_train,Y_train)
# Out:
# KNeighborsClassifier(n_neighbors=9)

# %%
Y_pred_KNN = knn.predict(X_test)

# %%
accuracy_score(Y_test,Y_pred_KNN )
# Out:
# 0.9830917874396136

# %%
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier(max_depth=500, random_state=300)

# %%
dtree.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(max_depth=500, random_state=300)

# %%
Y_pred_DT=dtree.predict(X_test)

# %%
accuracy_score(Y_test,Y_pred_DT )
# Out:
# 0.9806763285024155

# %%
def predict(X):
    Y_pred_KNN = knn.predict(X)
    print("Crime Type:",Y_pred_KNN)

    if Y_pred_KNN[0][0]==1:
      print("Predicted crime type is:",'Theft')

    if Y_pred_KNN[0][1]==1:
      print("Predicted crime type is:",'Hit and run')

    if Y_pred_KNN[0][2]==1:
      print("Predicted crime type is:",'Assault')

    if Y_pred_KNN[0][3]==1:
      print("Predicted crime type is:",'Kidnapping')

    if Y_pred_KNN[0][4]==1:
      print("Predicted crime type is:",'Murder')

# %%
predict([[2017,2,28,8,22.722247,75.915294]])
# Out:
# Crime Type: [[0 0 0 1 0]]
# Predicted crime type is: Kidnapping
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
